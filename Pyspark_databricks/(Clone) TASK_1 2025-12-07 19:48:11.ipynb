# %% [markdown]
# ## DataBricks_Learning1

# %% [markdown]
# ![](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql  
--Create a volume namely usage_metrics using sql magic command %sql
--Volume is a special storage location inside a catalog + schema where you can store files
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %% [markdown]
# ## Call the child notebook %run execute all the cells in 4_child_nd_dataload

# %%
# %run "/Workspace/Users/sachinchitte4@gmail.com/Pratice/4_child_nb_dataload"

# %%
# %python
spark.sql("SHOW TABLES").show()

# %%
# %python
print(spark.catalog.currentCatalog(), spark.catalog.currentDatabase())
